# %% [markdown]
# ### Visulization Basics

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %%
x = [1,2,4,5,6]
y = [3,4,8,15,12]

plt.plot(x,y)

# %%
x = [1,2,4,5,6]
y = [3,4,8,15,12]

plt.title('This is Mohamed\'s graph')
plt.plot(x,y)

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]


plt.title('Good linear graph', fontdict = {'fontname': 'Comic Sans MS', 'fontsize': 18})
plt.xlabel('time')
plt.ylabel('price')
plt.plot(x,y)

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]


plt.plot(x,y,label = 'y = 2x', color = 'blue')
plt.title('This is a second good linear blue graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]


plt.plot(x,y,label = 'y = 2x', color = 'black')
plt.title('This is a second good linear black graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]


plt.plot(x,y,label = 'y = 2x', color = 'red', linewidth= 4)
plt.title('This is a condensed linear graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]


plt.plot(x,y,label = 'y = 2x', color = 'black', marker = '*')
plt.title('This is a marked graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]


plt.plot(x,y,label = 'y = 2x', color = 'black', marker = '*', linestyle = '--')
plt.title('This is a marked, dashed graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]


plt.plot(x,y,label = 'y = 2x', color = 'black', marker = '*', linestyle = ':')
plt.title('This is a marked, separated graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]


plt.plot(x,y,'b>--',label = 'y = 2x') # b = blue, > = marker, -- = linestyle
plt.title('This is a marked, separated graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]

plt.plot(x,y,'g*:', label = '2x')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()

# %%
x = [0,1,2,4,5,6]
y = [0,2,4,8,10,12]
x2 = np.arange(0,4.5,0.5) # [0 , 0.5 , 1,....,4]

plt.plot(x,y,'r*--', label = 'equation 1')
plt.plot(x2,x2**2,'g>--', label = 'squared equation')

plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.legend()

# %%
x = [0,1,2,4,5,6]
y = [0,2,4,8,10,12]
x2 = np.arange(0,4.5,0.5) # [0 , 0.5 , 1,....,4]

plt.plot(x,y,'r*--', label = 'equation 1')
plt.plot(x2,x2**2,'g>--', label = 'squared equation')

plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.legend(loc = 'lower right') # control the location of the label, optimized by default

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]
x2 = np.arange(0,4,0.5) # [0 , 0.5 , 1,....,4]

plt.plot(x,y,'r*--', label = '2x')
plt.plot(x2,x2**2, label = 'blue')

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('This is a fairly good graph')
# control the values of the x and y axes
plt.xticks(np.arange(0,7))
plt.yticks(np.arange(0,13))

plt.legend()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]
x2 = np.arange(0,4,0.5) # [0 , 0.5 , 1,....,4]

plt.plot(x,y,'r*--', label = '2x')
plt.plot(x2,x2**2, label = 'blue')

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('This is a fairly good graph')

# control the values of the x and y axes
plt.xticks([0,1,2, 2.5,3,4,5,6]) # inserting 2.5 between integers
plt.yticks([i for i in range(0,7)]+[9])

plt.legend()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]
x2 = np.arange(0,4,0.5) # [0 , 0.5 , 1,....,4]

plt.plot(x,y,'r*--', label = '2x')
plt.plot(x2,x2**2, label = 'blue')

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('This is a fairly good graph')

# control the values of the x and y axes
plt.xticks([0,1,2, 2.5,3,4,5,6]) # inserting 2.5 between integers
plt.yticks(list(range(0,15,2))+[9])

# save to your computer, can save into various forms, pdf has good resolution
plt.savefig('firstfig.pdf')

plt.legend()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]
x2 = np.arange(0,4,0.5) # [0 , 0.5 , 1,....,4]

plt.plot(x,y,'r*--', label = '2x')
plt.plot(x2,x2**2, label = 'blue')

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('This is a fairly good graph')

# control the values of the x and y axes
plt.xticks([0,1,2, 2.5,3,4,5,6]) # inserting 2.5 between integers
plt.yticks(list(range(0,15,2))+[9])

# save jpg
plt.savefig('firstfig.jpg')

plt.legend()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]
x2 = np.arange(0,4,0.5) # [0 , 0.5 , 1,....,4]

plt.plot(x,y,'r*--', label = '2x')
plt.plot(x2,x2**2, label = 'blue')

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('This is a fairly good graph')

# control the values of the x and y axes
plt.xticks([0,1,2, 2.5,3,4,5,6]) # inserting 2.5 between integers
plt.yticks(list(range(0,15,2))+[9])

# save using dpi (dots per image) to increase resoultion, 720 default for pdf, 300 for other formats 
plt.savefig('firstfig2.jpg', dpi=100)

plt.legend()

# %%
# surrounding the equation by $$ visualizes its mathematical representation 
x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.title(r"$y=x^2$")

# other formates 
#plt.title(r"$y= x_i$")
#plt.title(r"$y= \cos(\pi . x)$")
#plt.title(r"$y= \cos(\pi x)$")
# more: https://matplotlib.org/stable/tutorials/text/mathtext.html
plt.plot(x,y)

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.title(r"$y= x^2$")
plt.plot(x,y, label =r"$y= x^2$" )
plt.legend(bbox_to_anchor = (1.4,1))

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
z = [1,4,6,8,12]

plt.title(r"$y= x^2$")
plt.plot(x,y, label =r"$y= x^2$" )
plt.plot(x,z, label =r"$z= x^2$" )
plt.legend(ncol=2)
# Out:
# []

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
z = [1,4,6,8,12]

plt.title(r"$y= x^2$")
plt.plot(x,y, label =r"$y= x^2$", color = 'green')
plt.plot(x,z, label =r"$z= x^2$" , color = 'grey')
plt.legend()
plt.legend(labelcolor = ['blue', 'red']) # controlling the color of the legend

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
z = [1,4,6,8,12]

plt.title(r"$y= x^2$")
plt.plot(x,y, label =r"$y= x^2$", color = 'green')
plt.plot(x,z, label =r"$z= x^2$" , color = 'grey')
plt.legend()
plt.legend(labelcolor = ['blue', 'red'], frameon = False) # removing the frame of legend

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
z = [1,4,6,8,12]

plt.title(r"$y= x^2$")
plt.plot(x,y, label =r"$y= x^2$", color = 'green')
plt.plot(x,z, label =r"$z= x^2$" , color = 'grey')
plt.legend()
plt.legend(labelcolor = ['blue', 'red'], title = 'keys') # adding info to our legend

# %%
# remove the border around the figures
x = [1,2,3,4,5]
y = [1,4,9,16,25]
z = [1,4,6,8,12]
plt.title(r"$y= x^2$")
plt.plot(x,y, label =r"$y= x^2$" )
plt.plot(x,z, label =r"$y= x^2$" )
plt.legend(labelcolor=["black", "red"], title = "key map")
ax = plt.gca() # get current axis 
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
# remove all borders 
x = [1,2,3,4,5]
y = [1,4,9,16,25]
z = [1,4,6,8,12]
plt.title(r"$y= x^2$")
plt.plot(x,y, label =r"$y= x^2$" )
plt.plot(x,z, label =r"$y= x^2$" )
plt.legend(labelcolor=["black", "red"], title = "key map")
ax = plt.gca() # get current axis 
ax.set_frame_on(False)

# %%
# remove everything around the figure  
x = [1,2,3,4,5]
y = [1,4,9,16,25]
z = [1,4,6,8,12]
plt.title(r"$y= x^2$")
plt.plot(x,y, label =r"$y= x^2$" )
plt.plot(x,z, label =r"$y= x^2$" )
plt.legend(labelcolor=["black", "red"], title = "key map")
ax = plt.gca() # get current axis 
ax.set_frame_on(False)
plt.xticks ([])
plt.yticks([])
plt.show()

# %% [markdown]
# ### 3D Plotting

# %%
plt.rcParams['figure.figsize'] = (10,8)
np.random.seed(31)
mu = 3
n=100

x = np.random.normal(mu, 1, size=n)
y = np.random.normal(mu, 1, size=n)
z = np.random.normal(mu, 1, size=n)
ax = plt.axes(projection='3d')
ax.scatter3D(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(50, 215)

# %%
plt.rcParams['figure.figsize'] = (8,6)

# %%
ax = plt.axes(projection='3d');

# %%
# ax = plt.axes(projection='3d')
ax.scatter3D(x, y, z);

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(x, y, z, s=100)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(x, y, z, s=100)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(200, 200);

# %%
omega = 2

z_line = np.linspace(0, 10, 100)
x_line = np.cos(omega*z_line)
y_line = np.sin(omega*z_line)

# %%
ax = plt.axes(projection='3d')
ax.plot3D(x_line, y_line, z_line, lw=4);

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]
x2 = np.arange(0,4, 0.5)

# control the dimensinos of the graph
plt.figure(figsize=(8,4), dpi=350)

plt.plot(x,y,'r*--',label = '2x')
plt.plot(x2,x2**2)
plt.legend()

plt.title('This is a perfect graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.xticks(np.arange(1,15))
plt.xticks(np.arange(0,13,2))
plt.show()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]
x2 = np.arange(0,4, 0.5)

# control the dimensinos of the graph
plt.figure(figsize=(12,4), dpi=350)

plt.plot(x,y,'r*--',label = '2x')
plt.plot(x2,x2**2)
plt.legend()

plt.title('This is a perfect graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.xticks(np.arange(1,15))
plt.xticks(np.arange(0,13,2))
plt.show()

# %% [markdown]
# ### Bar Charts

# %%
labels = ['A','B','C']
values = [1,7,4]

plt.bar(labels,values, color='#8f285b')
plt.show()

# %%
labels = ['A','B','C']
values = [1,7,4]

# plotting
plt.bar(labels,values, color='blue')
plt.yticks(np.arange(0,8,0.5))

plt.show()

# %%
labels = ['A','B','C']
values = [1,7,4]

# plotting
bars = plt.bar(labels,values, color='blue')

# editing
bars[0].set_hatch('/')
bars[1].set_hatch('o')
bars[2].set_hatch('x')

plt.show()

# %%
labels = ['A','B','C']
values = [1,7,4]

# plotting
bars = plt.bar(labels,values, color='blue')[0].set_hatch('/')

plt.show()

# %%
labels = ['A','B','C']
values = [1,7,4]

bars = plt.bar(labels,values, color='blue')
patterns = ['/','o','x']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.show()

# %% [markdown]
# ### Magic

# %% [markdown]
# **allows us to zoom with perfect resolution and save the plot with any adjustments**

# %%
# %matplotlib notebook 
labels = ['A','B','C']
values = [1,7,4]

bars = plt.bar(labels,values, color='blue')
patterns = ['/','o','x']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
x = [1,2,4,5,6]
y = [2,4,8,10,12]
x2 = np.arange(0,4, 0.5)

plt.plot(x,y)
plt.plot(x2,x2**2,'r*--',label = '2x')
plt.legend()

plt.title('This is a second perfect graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
x = [1,2,4,5,6]
y = [2,4,8,10,12]
x2 = np.arange(0,4, 0.5)

plt.plot(x,y)
plt.plot(x2,x2**2,'r*--',label = '2x')
plt.grid(True) # grid plotting
plt.legend()

plt.title('This is a second perfect graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]

# removing the continous line by setting linestyle to ''
# controlling the markersize
plt.plot(x,y,color = 'blue', marker = 'x', linestyle = '',markersize =10)
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# alpha controls the transperancy of the marker, [0,1] scale
plt.plot(x,y,'b<',alpha=0.2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,40]

plt.plot(days,max_t,label='max')
plt.plot(days,min_t,label='min')
plt.plot(days,avg_t,label='avg')

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Legend at different location with shadow enabled and fontsize set to large
plt.ioff()
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(shadow=True,fontsize='large')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,85,27]

plt.bar(company, revenue, color = 'blue')
plt.title('US Technology Stock')
plt.xlabel('Company')
plt.ylabel('Revenue ($B)')
plt.show()

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,85,27]
profit=[40,7,34,12]
xpos = np.arange(len(company)) # 0 , 1 , 2, 3

plt.figure(figsize = (10,4))
plt.bar(company,revenue, width=0.4, label="Revenue") # x = 0, x = 0.4 
plt.bar(xpos-0.4,profit, width=0.4,label="Profit")# x = -.4  , x = 0
plt.xticks(xpos,company)
plt.ylabel("Revenue($B)")
plt.title('US Technology Stocks')
plt.legend()
plt.show()

# %% [markdown]
# ### Pie Charts

# %%
exp_vals = [1400,600,300,300,250] #expenses
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car","Other Utilities"]
plt.pie(exp_vals,labels=exp_vals)
plt.show()

# %%
# specifying the percentage of each secotr and the radius of the cirle
plt.pie(exp_vals, labels=exp_labels, autopct = '%0.5f%%', radius = 3)
plt.show()

# %%
plt.pie(exp_vals, labels=exp_labels, autopct = '%0.3f%%', radius = 3)
plt.show()

# %%
# adding shadow and exploding certain sectors 
plt.pie(exp_vals,labels=exp_labels,shadow=True,autopct='%.2f%%',radius = 2,explode = [0,0.6,0,0,0])
plt.show()

# %%
# adding start angle
plt.pie(exp_vals,labels=exp_labels,shadow=True,autopct='%.2f%%',radius = 2,explode = [0,0.6,0,0,0], startangle = 180)
plt.show()

# %%
mx = -1
sector = ''
percent = 1
for i in range(len(exp_labels)):
    if exp_vals[i] >mx:
     mx = exp_vals[i]
     percent = mx/sum(exp_vals)
     sector = exp_labels[i]
print('The most prominent sector is',sector,'with percentage of:',percent*100)
# Out:
# The most prominent sector is Home Rent with percentage of: 49.122807017543856

# %% [markdown]
# ### Working on CV Data

# %% [markdown]
# #### Gas prices

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
gas = pd.read_csv('gas_prices.csv')
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
us_gas = gas.USA 
canda_gas = gas.Canada

plt.figure(figsize=(10,5))
plt.plot(gas.Year, us_gas,label = 'USA')
plt.plot(gas.Year, canda_gas,label = 'Canda')
plt.legend()

plt.title('USA Vs Canada')
plt.xlabel('Years')
plt.ylabel('Price')

plt.xticks(gas.Year)
plt.show()

# %%
years = gas.Year
plt.figure(figsize=(10,5)) # before plotting
plt.title('USA, Canada, and South Korea')
plt.plot(years,gas['USA'],color = "blue",marker = '*', label = 'USA')
plt.plot(years, gas['Canada'], color = 'yellow', marker = 'o',label = 'Canada')
plt.plot(gas.Year , gas["South Korea"] , color= 'green', label= "South Korea", marker = ">")
plt.legend()


plt.xticks(years)
plt.xlabel('Years')
plt.ylabel('USD')
plt.xticks(years[::2])
plt.show()

# %%
gas.describe()
# Out:
#               Year  Australia     Canada     France    Germany      Italy  \
# count    19.000000  18.000000  19.000000  19.000000  19.000000  19.000000
# mean   1999.000000   2.348889   2.086842   4.407895   4.224737   4.645789
# std       5.627314   0.845931   0.786618   1.167531   1.425749   1.146610
# min    1990.000000   1.630000   1.380000   3.410000   2.650000   3.570000
# 25%    1994.500000   1.780000   1.590000   3.605000   3.370000   3.805000
# 50%    1999.000000   1.955000   1.730000   3.870000   3.530000   4.390000
# 75%    2003.500000   2.587500   2.180000   4.700000   4.915000   4.940000
# max    2008.000000   4.450000   4.080000   7.510000   7.750000   7.630000
#
#            Japan     Mexico  South Korea         UK        USA
# count  19.000000  19.000000    19.000000  19.000000  19.000000
# mean    3.820526   1.781579     3.835789   4.392632   1.592105
# std     0.696615   0.462148     1.226170   1.455170   0.663355
# ...

# %%
gas.shape
# Out:
# (19, 11)

# %%
plt.figure(figsize=(8,5))
plt.title('Fierce Comparison')
countries = ["USA", "Canada", "Italy", "UK" , "France"]
for i in countries:
    plt.plot(gas.Year,gas[i],label=i)

plt.legend()
plt.xlabel('Years')
plt.ylabel('USD')
plt.xticks(gas.Year[::2])
plt.show()

# %%
plt.figure(figsize = (12,10))
plt.title('Even a more hot comparison')

for i in gas.columns:
    if i !='Year':
        plt.plot(gas.Year,gas[i],label=i)

plt.legend()
plt.xlabel('Years')
plt.ylabel('USD')
plt.xticks(gas.Year[::2])
plt.show()

# %% [markdown]
# #### Fifa

# %%
fifa = pd.read_csv('fifa_data.csv')
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
fifa.columns.to_list() # all attributes
# Out:
# ['Unnamed: 0',
#  'ID',
#  'Name',
#  'Age',
#  'Photo',
#  'Nationality',
#  'Flag',
#  'Overall',
#  'Potential',
#  'Club',
#  'Club Logo',
#  'Value',
#  'Wage',
#  'Special',
#  'Preferred Foot',
#  'International Reputation',
#  'Weak Foot',
#  'Skill Moves',
#  'Work Rate',
#  'Body Type',
#  'Real Face',
#  'Position',
#  'Jersey Number',
#  'Joined',
#  'Loaned From',
#  'Contract Valid Until',
#  'Height',
#  'Weight',
#  'LS',
#  'ST',
#  'RS',
#  'LW',
#  'LF',
#  'CF',
#  'RF',
#  'RW',
#  'LAM',
#  'CAM',
#  'RAM',
#  'LM',
#  'LCM',
#  'CM',
#  'RCM',
#  'RM',
#  'LWB',
#  'LDM',
#  'CDM',
#  'RDM',
#  'RWB',
#  'LB',
#  'LCB',
#  'CB',
#  'RCB',
#  'RB',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
# ...

# %%
for i in fifa.Name:
    print(i)
# Out:
# L. Messi
# Cristiano Ronaldo
# Neymar Jr
# De Gea
# K. De Bruyne
# E. Hazard
# L. Modrić
# L. Suárez
# Sergio Ramos
# J. Oblak
# R. Lewandowski
# T. Kroos
# D. Godín
# David Silva
# N. Kanté
# P. Dybala
# H. Kane
# A. Griezmann
# M. ter Stegen
# T. Courtois
# Sergio Busquets
# E. Cavani
# M. Neuer
# S. Agüero
# G. Chiellini
# K. Mbappé
# M. Salah
# Casemiro
# J. Rodríguez
# L. Insigne
# Isco
# C. Eriksen
# Coutinho
# P. Aubameyang
# M. Hummels
# Marcelo
# G. Bale
# H. Lloris
# G. Higuaín
# Thiago Silva
# S. Handanovič
# G. Buffon
# S. Umtiti
# M. Icardi
# K. Koulibaly
# P. Pogba
# K. Navas
# R. Lukaku
# C. Immobile
# Jordi Alba
# D. Mertens
# J. Vertonghen
# M. Hamšík
# I. Rakitić
# Piqué
# L. Sané
# Bernardo Silva
# Ederson
# S. Mané
# V. van Dijk
# R. Sterling
# Roberto Firmino
# R. Varane
# M. Verratti
# Alex Sandro
# Douglas Costa
# T. Müller
# Thiago
# M. Reus
# Azpilicueta
# L. Bonucci
# T. Alderweireld
# M. Pjanić
# M. Benatia
# M. Özil
# Fernandinho
# Iniesta
# M. Škriniar
# ...

# %%
players_names = fifa['Name'].to_list()
players_names
# Out:
# ['L. Messi',
#  'Cristiano Ronaldo',
#  'Neymar Jr',
#  'De Gea',
#  'K. De Bruyne',
#  'E. Hazard',
#  'L. Modrić',
#  'L. Suárez',
#  'Sergio Ramos',
#  'J. Oblak',
#  'R. Lewandowski',
#  'T. Kroos',
#  'D. Godín',
#  'David Silva',
#  'N. Kanté',
#  'P. Dybala',
#  'H. Kane',
#  'A. Griezmann',
#  'M. ter Stegen',
#  'T. Courtois',
#  'Sergio Busquets',
#  'E. Cavani',
#  'M. Neuer',
#  'S. Agüero',
#  'G. Chiellini',
#  'K. Mbappé',
#  'M. Salah',
#  'Casemiro',
#  'J. Rodríguez',
#  'L. Insigne',
#  'Isco',
#  'C. Eriksen',
#  'Coutinho',
#  'P. Aubameyang',
#  'M. Hummels',
#  'Marcelo',
#  'G. Bale',
#  'H. Lloris',
#  'G. Higuaín',
#  'Thiago Silva',
#  'S. Handanovič',
#  'G. Buffon',
#  'S. Umtiti',
#  'M. Icardi',
#  'K. Koulibaly',
#  'P. Pogba',
#  'K. Navas',
#  'R. Lukaku',
#  'C. Immobile',
#  'Jordi Alba',
#  'D. Mertens',
#  'J. Vertonghen',
#  'M. Hamšík',
#  'I. Rakitić',
#  'Piqué',
#  'L. Sané',
#  'Bernardo Silva',
#  'Ederson',
#  'S. Mané',
# ...

# %%
print(f"Number of players in FIFA 2019 is {fifa.shape[0]}\nNumber of attributes per player is {fifa.shape[1]}")
# Out:
# Number of players in FIFA 2019 is 18207
# Number of attributes per player is 89

# %%
if "M. Salah" in fifa.Name.values:
    print('GO MO GO MO GO MO!!')
# Out:
# GO MO GO MO GO MO!!

# %%
plt.hist(fifa.Overall) # Overall corresponds to the overall power of the player in FIFA 2019
plt.xticks(np.arange(40,100,4))
plt.yticks([0,2, 10,14 , 20, 30, 1000, 2000, 3000, 4000, 4500, 5000, 6000])
plt.show() # the distribution is approximately normal

# %%
power_above_or_equal_90 = fifa['Name'][fifa.Overall>=90]
print(len(power_above_or_equal_90))
# Out:
# 14

# %%
plt.figure(figsize=(10,10))
players = fifa.Name[:7]
overall = fifa.Overall[:7]
plt.bar(players,overall)
plt.yticks([80,85,90, 95])
plt.show()

# %%
left_leg = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
left_leg
# Out:
# 4211

# %%
right_leg = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]
plt.pie([left_leg, right_leg],labels = ['Left Foot','Right Foot'], autopct='%.2f%%')
plt.show()

# %%
fifa.Nationality.value_counts()
# Out:
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
#              ...
# Fiji            1
# Indonesia       1
# Palestine       1
# Ethiopia        1
# Grenada         1
# Name: Nationality, Length: 164, dtype: int64

# %%
player_country = ["Argentina", "Portugal",  "Brazil" , "England"]
numbers = []
for country in player_country:
    numbers.append(fifa.loc[fifa['Nationality']==country].count()[0])
numbers
# Out:
# [937, 322, 827, 1662]

# %%
plt.pie(numbers,labels=player_country)
plt.show()

# %%
plt.bar(playercountry, countrynumbers)
plt.show()

# %%
counter =0
for i in fifa.Nationality:
    if i not in player_country:
        counter +=1
player_country.append('Others')
numbers.append(counter)
plt.pie(numbers,labels=player_country)
plt.show()

# %%
top_countries = fifa.Nationality.value_counts()[:13].to_list()
country_names = fifa.Nationality.value_counts().index[:13]

country_names = country_names.to_list()
country_names.append('Others')
all_top_countries = sum(top_countries)

others = sum(list(fifa.Nationality.value_counts())) - all_top_countries
top_countries.append(others)

plt.pie(top_countries, labels= country_names, autopct = "%.2f%%",radius= 2)
plt.show()

# %%
fifa.Weight
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
# check if any value is NaN in a pandas dataframe 
fifa.Weight.isnull().values.any()
# Out:
# True

# %%
fifa.Weight = [x.strip('lbs') if type(x)==str else x for x in fifa.Weight]
fifa.Weight[0]
# Out:
# '159'

# %%
plt.xkcd()
plt.style.use('seaborn-deep')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
plt.scatter(x,y , s = 100)
plt.grid(True)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.title("Hey All")
plt.show()

# %%
plt.style.use('seaborn-deep')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
plt.scatter(x,y , s = 100)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.title("Hey All")
plt.show()

# %%
plt.xkcd()
plt.style.use('seaborn-pastel')
plt.figure()


x = [5, 1, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]


# first subplot 
plt.subplot(2,2,1)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.scatter(x,y)


# second subplot 
plt.subplot(2,2,2)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.plot(x,y, "k*")


# Third subplot 
plt.subplot(2,2,3)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.plot(x,y, "ro")


# forth subplot 
plt.subplot(2,2,4)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.plot(x,y, 'b>')




plt.show()

# %% [markdown]
# ### Reading Videos

# %%
from IPython.display import HTML
url = 'http://jakevdp.github.io/downloads/videos/double_pendulum_xkcd.mp4'
HTML('<video controls alt="animation" src="{0}">'.format(url))
# Out:
# <video controls alt="animation" src="http://jakevdp.github.io/downloads/videos/double_pendulum_xkcd.mp4">

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('p693u53Q10U')

# %%
YouTubeVideo('p693u53Q10U', width=1000, height=570)

# %%
from IPython.display import Math
Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx')
# Out:
# $\displaystyle F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$

# %%
Math(r'f(x) = 2x^4')
# Out:
# $\displaystyle f(x) = 2x^4$

# %%
from IPython.display import Image

# by default Image data are embedded
Embed = Image('https://i.pinimg.com/564x/7e/8f/bf/7e8fbf02865d4c04435a5c89b8d727a2.jpg')

# if kwarg `url` is given, the embedding is assumed to be false
SoftLinked = Image(url='https://4.bp.blogspot.com/-hAHPu5tbMaI/WEQ2uDx33-I/AAAAAAAAABM/jLlTq_9F9nk_OkXI5VQK_Ue_7CPhCMc8QCLcB/s1600/David%2BBeckham21.jpg')

# In each case, embed can be specified explicitly with the `embed` kwarg
# ForceEmbed = Image(url='http://scienceview.berkeley.edu/view/images/newview.jpg', embed=True)

# %%
Embed

# %%
type(Embed)
# Out:
# IPython.core.display.Image

# %%
SoftLinked
# Out:
# <img src="https://4.bp.blogspot.com/-hAHPu5tbMaI/WEQ2uDx33-I/AAAAAAAAABM/jLlTq_9F9nk_OkXI5VQK_Ue_7CPhCMc8QCLcB/s1600/David%2BBeckham21.jpg"/>

# %%
The100 = Image('https://images-na.ssl-images-amazon.com/images/I/91Elu5k9oIL._SL1500_.jpg')
The100

# %%
from matplotlib.animation import FuncAnimation
from itertools import count
import random

index = count()
x = []
y = []

def animate():
    x.append(next(index))
    y.append(random.ranint(0,5))
    plt.cla()
    plt.plot(x,y)

ani = FuncAnimation(plt.gcf(), animate, interval = 500)

plt.show()
